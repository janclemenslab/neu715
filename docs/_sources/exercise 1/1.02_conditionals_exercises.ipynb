# %% [markdown]
# # Conditionals — exercises

# %% [markdown]
# Work in the answer cells below. Predict an answer before running code, then
# compare the result with your prediction. The code cells provide starting
# values, not completed solutions. Deliberately faulty code is shown as text;
# copy it into an answer cell when you are ready to repair it.
#
# Every complete exercise session has **40 trials**. `1` means correct and `0`
# means incorrect. The exercise training rule is **accuracy > 0.66**. Because
# one response is 1/40 = 0.025 of the session, 26/40 = 0.65 does not qualify,
# whereas 27/40 = 0.675 does.

# %% [markdown]
# ## Exercise 1: predict comparisons
#
# For `n_correct = 26` and `n_trials = 40`, predict each result, then check:
#
# ```python
# n_correct > 26
# n_correct >= 26
# n_correct == 26
# n_correct != 26
# n_correct / n_trials > 0.66
# n_correct / n_trials == 0.65
# ```
#
# **Your predictions:** …

# %%
n_correct = 26
n_trials = 40
# Display the comparisons and check your predictions.

# %% [markdown]
# ## Exercise 2: score one trial
#
# The labels `"sound"` and `"no sound"` describe both what happened (`target`)
# and what the animal reported (`response`). Write an if/else statement that
# stores **1** in `outcome` when the labels match and **0** otherwise.
# Print `outcome`.
#
# Test all four combinations by editing the input values:
#
# | Target | Response | Expected outcome |
# | --- | --- | --- |
# | sound | sound | 1 |
# | sound | no sound | 0 |
# | no sound | sound | 0 |
# | no sound | no sound | 1 |
#
# Explain why a "no sound" response can be correct.

# %%
target = "no sound"
response = "no sound"
# Your if/else here.

# %% [markdown]
# ## Exercise 3: fix the training rule
#
# This suggested code runs but applies the wrong rule:
#
# ```python
# n_correct = 25
# n_trials = 40
# accuracy = n_correct / n_trials
# if n_correct > 26:
#     print("criterion not met")
# else:
#     print("well-trained")
# ```
#
# Modify below using `accuracy > 0.66` as the criterion, instead of `n_correct`. As a check, print the accuracy before the `if` statement. Test with 25, 26, and 27 correct responses.

# %%
# Your repaired code here.

# %% [markdown]
# ## Exercise 4: decide using accuracy
#
# Calculate `accuracy` from the counts below. Use it in an if/else statement
# that stores `"well-trained"` or `"criterion not met"` in `training_status`.
# Print the accuracy and status. Use the strict rule **accuracy > 0.66**.
#
# Before using supplied checks, choose one count that you expect to qualify and
# one that you expect not to qualify. Then check 26, 27, 0, and 40 correct responses.

# %%
n_correct = 27
n_trials = 40
# Calculate, decide, and display.

# %% [markdown]
# ## Optional Exercise 5: describe the transition separately
#
# Use `if`, `elif`, and `else` to print one of three messages:
#
# - At least 27 correct: `"well-trained"`.
# - Exactly 26 correct: `"65% correct: criterion not met"`.
# - Fewer than 26 correct: `"below 65% correct: criterion not met"`.
#
# Test all three branches. Explain why no whole-number correct count produces
# exactly 66% in a 40-trial session.

# %%
n_correct = 26
# Your code here.

# %% [markdown]
# ## Optional Exercise 6: check whether a count is possible
#
# A completed 40-trial session cannot have a negative correct count or more
# than 40 correct. Use two comparisons and `and` to store whether a count is
# possible in `valid_count`. Test -1, 0, 40, and 41.
#
# Use only integer inputs for this exercise.

# %%
n_correct = 41
# Your code here.
