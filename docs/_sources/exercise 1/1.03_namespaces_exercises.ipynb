# %% [markdown]
# # Namespaces — exercises

# %% [markdown]
# Work in the answer cells below. Predict an answer before running code, then
# compare the result with your prediction. The code cells provide starting
# values, not completed solutions. Deliberately faulty code is shown as text;
# copy it into an answer cell when you are ready to repair it.
#
# Every complete exercise session has **40 trials**. `1` means correct and `0`
# means incorrect. The exercise training rule is **accuracy > 0.66**. Because
# one response is 1/40 = 0.025 of the session, 26/40 = 0.65 does not qualify,
# whereas 27/40 = 0.675 does. Short practice excerpts are labelled separately.

# %% [markdown]
# ## Exercise 1: stored values
#
# Predict the three printed values before running the cell. Which assignment
# would you need to rerun to make the accuracy agree with the updated count?

# %%
n_correct = 26
n_trials = 40
accuracy = n_correct / n_trials
saved_count = n_correct
n_correct = 27
print(n_correct)
print(saved_count)
print(accuracy)

# %% [markdown]
# **Your prediction and explanation:** …
#
# In the next cell, recalculate and update `accuracy` and `saved_count`, then display both.

# %%
# Your code here.

# %% [markdown]
# ## Exercise 2: rerunning a cell
#
# Predict what happens when you run both cells below once and then run only the
# second cell a second time. These are counts while scoring a session, not yet a
# completed 40-trial result.

# %%
n_correct_so_far = 5

# %%
n_correct_so_far = n_correct_so_far + 1
print(n_correct_so_far)

# %% [markdown]
# **Your explanation:** …
