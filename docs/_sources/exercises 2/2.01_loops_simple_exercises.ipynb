# %% [markdown]
# # Loops — exercises

# %% [markdown]
# Work in the answer cells below. Predict an answer before running code, then
# compare the result with your prediction. The code cells provide starting
# values, not completed solutions. Deliberately faulty code is shown as text;
# copy it into an answer cell when you are ready to repair it.
#
# Every complete exercise session has **40 trials**. `1` means correct and `0`
# means incorrect. The exercise training rule is **accuracy > 0.66**. Because
# one response is 1/40 = 0.025 of the session, 26/40 = 0.65 does not qualify,
# whereas 27/40 = 0.675 does. Short practice excerpts are labelled separately.
#
# Use `for index in range(len(outcomes))` for a complete session. Shorter excerpts use their own list name.

# %% [markdown]
# ## Exercise 1: print each outcome
#
# Use `for index in range(len(practice_outcomes))` to print each item in this **five-trial practice excerpt** on
# its own line. Print `"Finished"` once, after the loop. This input differs from
# the worked lecture example.

# %%
practice_outcomes = [0, 1, 0, 1, 1]
# Your loop here.

# %% [markdown]
# ## Exercise 2: repair the indentation
#
# This code prints only the last outcome. Predict which value that is, then copy
# and fix the code so that each outcome is printed. Next, move one line so that
# `"Finished"` is printed once for every outcome.
#
# ```python
# practice_outcomes = [1, 0, 0, 1, 0]
# for index in range(len(practice_outcomes)):
#     current_outcome = practice_outcomes[index]
# print(current_outcome)
# print("Finished")
# ```

# %%
# Your repaired code here.

# %% [markdown]
# ## Exercise 3: repair the counter
#
# Trace this short practice excerpt. This code is supposed to through `practice_outcomes` and print "Correct", if the outcome is 1. What does the code actually print? Fix the code?
#
# ```python
# practice_outcomes = [1, 1, 0, 1, 0]
# for index in range(len(practice_outcomes)):
#     outcome = 0
#     if outcome == 1:
#         print('Correct!')
# ```

# %%
# Your repaired outcome reporting code here.

# %% [markdown]
# ## Exercise 4: repair the counter
#
# Trace this short practice excerpt. What does the code print? What should the
# count be? Move the reset to the right place and check your repair.
#
# ```python
# practice_outcomes = [1, 1, 0, 1, 0]
# for index in range(len(practice_outcomes)):
#     n_correct = 0
#     if practice_outcomes[index] == 1:
#         n_correct = n_correct + 1
# print(n_correct)
# ```

# %%
# Your repaired counting code here.

# %% [markdown]
# ## Exercise 5: count a complete session
#
# Here are the 40 outcomes for a new animal. Count correct responses by hand
# before coding. Write a loop that starts `n_correct` at zero and increments
# it for each correct outcome. Display the final count after the loop.
#
# Also use `len(outcomes)` to confirm there are 40 trials.

# %%
outcomes = [1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1]
# Count and display the correct responses.

# %% [markdown]
# **Your hand-counted result:** …
#
# ## Exercise 6: complete the analysis
#
# Put the full analysis in the cell below. Start from its supplied data so
# the cell works even if Exercise 4 has not been run.
#
# 1. Initialise a correct-response count.
# 2. Loop over the outcomes and update the count for correct trials.
# 3. Determine `n_trials` from the list length.
# 4. Calculate `accuracy = n_correct / n_trials`.
# 5. Decide whether `accuracy > 0.66` and set `training_status`.
# 6. Print the animal's name, correct count, trial count, accuracy, and status.
#
# Predict the report by hand. Then rerun your whole cell: the result should
# stay the same rather than accumulating another session's count.

# %%
animal_name = "Nori"
outcomes = [1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1]
# Your complete analysis here.

# %% [markdown]
# ## Collect results as well as counts
#
# The next two exercises practise building lists and retaining trial positions.

# %% [markdown]
# ## Exercise 7: build readable labels
#
# For this practice excerpt, build a list called `labels` with `"correct"`
# for each 1 and `"incorrect"` for each 0. Preserve trial order.
#
# Check that the output length matches the input length. Explain why the
# empty output list belongs before the loop.

# %%
practice_outcomes = [0, 1, 1, 0]
# Your code here.

# %% [markdown]
# ## Exercise 8: identify incorrect trials
#
# Use `range(len(outcomes))` and indexing to collect the **trial numbers** of
# incorrect responses in `incorrect_trials`.

# %%
outcomes = [1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1, 1, 0, 1]
# Your code here.

# %% [markdown]
# ## Optional Exercise 9: select qualifying session counts
#
# Each value below is the total correct count for a separate **40-trial
# session**, not an individual trial outcome. Collect the counts that meet
# the training rule into `qualifying_counts`.
#
# Predict which values will be kept, including what happens to 26.

# %%
session_counts = [20, 25, 26, 27, 40]
# Your code here.

# %% [markdown]
# ## Optional Exercise 10: score the raw reports
#
# So far, trial outcomes have already been scored as 1 or 0. Here are raw
# target and response labels for a **four-trial practice excerpt**.
# Items at the same index belong to the same trial.
#
# Loop over the indices. Compare the corresponding response and target;
# append 1 to `scored_outcomes` when they match and 0 otherwise.
# Check the result by hand using the single-trial rule from Conditionals.

# %%
targets = ["sound", "no sound", "sound", "no sound"]
responses = ["sound", "no sound", "no sound", "sound"]
# Your code here.
