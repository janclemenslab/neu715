# %% [markdown]
# # Dungeon Escape

# %% [markdown]
# ## Setup and command reference
# Run the supplied setup. The first room is fully visible (`visible=True`).
# Rooms are visible by default. Use `visible=False` for darkness; moving then reveals floor tiles.
# Imports make the game commands available. You do not need to write the setup.
#
# | Command | Effect / returned value |
# | --- | --- |
# | `forward()` | Returns `"success"` after moving, `"wall"` when blocked, or `"exit"` when moving into the exit door. |
# | `left()`, `right()` | Turn without moving. |
# | `reset()` | | `reset()` | Restores your position in the room to the start. |

# %%
from blockworld import (
    forward, left, right, reset,
    load, new_practice_room, new_hallway, new_twisty_room, toss_dice
)
load(["#######", "#>..E##", "#######"], visible=True)

# %% [markdown]
# ## Exercise 1: A straight corridor
# Predict the instructions need to reach the exit.
# Then implement your escape plan.

# %%
load(["######", "#>..E#", "######"], theme='turtle')
# Write your escape plan with a for loop

# %% [markdown]
# ## Exercise 2: Don't repeat yourself
#
# We are running the same command repeatedly. This become tedious for long corridors.
#
# Define the number of forward steps to reach the exit and implement your plan using a for loop.
#
# In each step, save the result of your forward movement (moved, wall, exit) and print it.

# %%
load(["#############", "#>.........E#", "#############"], theme='beetle')
# Write your escape plan with a for loop

# %% [markdown]
# ### Exercise 3: A corridor with two corners
# We now have a room with two corners.
#
# Again, plan your escape. Then implement the plan with individual instructions.

# %%
load(["#####", "#>..#",  "###.#", "##E.#", "#####"], theme='mouse')

# Automate the plan

# %% [markdown]
# ### Exercise 3: Automate this!!
# Let's use the solution from exercise 2 as a starting point. Write a for loop in which you only run forward and save and print result of each step (this isthe solution to exercise 2).
#
# This obviously does not work because you have to turn right when hitting the wall.
#
# Add an `if` statement inside the for-loop that makes you turn right if you hit the wall.

# %%
load(["#####", "#>..#",  "###.#", "##E.#", "#####"], theme='fox')

# first copy your solution from the previous exercise, inspect its behavior and modify it to reach the exit.

# %% [markdown]
# ### Exercise 4: Adapt your solution to a new room
# Here's a different room. Test the solution from previous exercise. Why does it fail?
#
# Modify it to escape!

# %%
load(["#####", "##E.#", "###.#", "#>..#",  "#####"], theme='robot')

# first copy your solution from the previous exercise, inspect its behavior and modify it to reach the exit.

# %% [markdown]
# ### Optional Exercise 5: Find a more general solution
# Here's a yet another room for which neither of the above exit strategies work.
#
# Solve it using a for loop!
#
# Hint: One strategy is to turn left or right randomly if you run in the a wall. `toss_dice()` returns True or False at random. You can use it to make your strategy more variable.
#
# The random turning strategy may let you escape, but it is obviously not optimal. Can you come up with an even better strategy?

# %%
new_twisty_room(theme="penguin", delay=0)  # generates random layouts, delay=0 makes running the program faster.

# define a variable strategy!
