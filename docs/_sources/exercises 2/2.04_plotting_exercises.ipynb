# %% [markdown]
# # Plotting — exercises

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1: a labelled plot
# Plot voltage against time using both lists. Label both axes with units.
# Before running it, predict where the 35 mV point will appear.

# %%
times_ms = [0, 2, 4, 6, 8]
voltage_mv = [-65, -60, 35, -58, -63]
# Plot and label the recording.

# %% [markdown]
# ## Exercise 2: change the view
# Copy your plot. Display 2–6 ms on the x-axis and -70–50 mV on the y-axis.
# Do the stored lists change when you change the limits? Explain why.

# %%
# Plot again and set both axis limits before show.

# %% [markdown]
# ## Exercise 3: repair the plot arguments
# The labels below describe the intended axes, but the inputs are reversed.
# Write the corrected plot and use one known point to check it.
#
# ```python
# plt.plot(voltage_mv, times_ms)
# plt.xlabel("Time (ms)")
# plt.ylabel("Membrane voltage (mV)")
# plt.show()
# ```

# %%
# Repair the plotting call and keep the axis labels.

# %% [markdown]
# ## Exercise 4: construct a specified plot
# Create two lists describing four voltage samples. The time points must
# be 0, 3, 6, and 9 ms, and the highest voltage must be 20 mV at 6 ms.
# Choose the other voltages below zero. Plot and label your data.

# %%
# Create the two lists and the plot.
